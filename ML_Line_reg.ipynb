# %% [markdown]
# # LINEAR REGRESSION 2. TRUE

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the dataset
boston = datasets.load_boston()
target = boston.target
data = boston.data

# %%
# Use only one feature
boston_X = data[:, np.newaxis, 2]

# %%
# Split the data into training/testing sets
boston_X_train = boston_X[:-20]
boston_X_test = boston_X[-20:]

# %%
# Split the targets into training/testing sets
boston_y_train = boston.target[:-20]
boston_y_test = boston.target[-20:]

# %%
# Create linear regression object
reg = linear_model.LinearRegression()

# %%
# Train the model using the training sets
reg.fit(boston_X_train, boston_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
boston_y_pred = reg.predict(boston_X_test)

# %%
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(boston_y_test, boston_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(boston_y_test, boston_y_pred))
# Out:
# Coefficients:
#  [-0.65457086]
# Mean squared error: 18.56
# Variance score: 0.21

# %%
# Plot outputs
plt.scatter(boston_X_test, boston_y_test,  color='indigo')
plt.plot(boston_X_test, boston_y_pred, color='red', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
def estimate_coef(x, y): 
    n = np.size(x)

    # mean of x and y vector 
    m_x, m_y = np.mean(x), np.mean(y) 

    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 

    # calculating regression coefficients 
    b_1 = SS_xy / SS_xx 
    b_0 = m_y - b_1*m_x 

    return(b_1)

# %%
for i in range(0,13):
    #porto = np.linspace(np.min(target), np.max(target), 20)
    #xo = porto*k[i]
    fig = plt.figure(figsize=(10,20))
    plt.subplot(7,2,i+1)
    plt.scatter(data[:,i], target, alpha=0.5)
    z = np.polyfit(data[:,i],target, 1)
    p = np.poly1d(z)
    plt.plot(data[:,i],p(data[:,i]),"k--", linewidth=3)   
    #plt.plot(xo)
    plt.title('Scatter plot'+str(i+1))
    plt.xlabel('x')
    plt.ylabel('y')
    

    
plt.show()

# %%
for i in range(0,13):
    
    #porto = np.linspace(np.min(data[:,i]), np.max(data[:,i]), 1000)
    #xo = porto*k[i]
    z = np.polyfit(data[:,i],target, 1)
    p = np.poly1d(z)
    plt.plot(data[:,i],p(data[:,i]),"k--", linewidth=2)               
    fig = plt.figure(figsize=(10,20))
    plt.subplot(7,2,i+1)
    #plt.scatter(data[:,i], target, alpha=0.5)
    #plt.plot(xo)
    plt.title('Scatter plot'+str(i+1))
    plt.xlabel('x')
    plt.ylabel('y')
    

    
plt.show()
